# %%
import pandas as pd
pd.set_option('display.max_columns',10)

# %%
df=pd.read_csv(r"C:\Users\ROHAN SANJAY\DOWNLOADS\Flipkart_Mobiles.csv")

# %%
df
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# ...

# %%
f=df['Memory'].str.strip()

# %%
f.to_csv("D:\Flipkart_new.csv")

# %%
k=df.fillna(method='pad')
k
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# ...

# %%
k.to_csv("D:\Flipkart_new_1.csv")

# %%
k.drop(['Storage'],axis=1,inplace=True)
k
# Out:
#         Brand   Model            Color Memory  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB     4.5          11990
# ...       ...     ...              ...    ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB     4.2          20350
#
#       Original Price
# 0              15990
# 1              15990
# 2              17990
# 3              17990
# 4              15990
# ...

# %%
k.to_csv("D:\Flipkart_new_2.csv")
df.count()
# Out:
# Brand             3114
# Model             3114
# Color             3114
# Memory            3071
# Storage           3075
# Rating            2970
# Selling Price     3114
# Original Price    3114
# dtype: int64

# %%
x=df.dropna()
x.count()
# Out:
# Brand             2897
# Model             2897
# Color             2897
# Memory            2897
# Storage           2897
# Rating            2897
# Selling Price     2897
# Original Price    2897
# dtype: int64

# %%
x.to_csv("D:\Flipkart_new_3.csv")

# %%
n=pd.read_csv("D:\Flipkart_new_2.csv")

# %%
n
# Out:
#       Unnamed: 0    Brand   Model            Color Memory  Rating  \
# 0              0     OPPO     A53  Moonlight Black   4 GB     4.5
# 1              1     OPPO     A53       Mint Cream   4 GB     4.5
# 2              2     OPPO     A53  Moonlight Black   6 GB     4.3
# 3              3     OPPO     A53       Mint Cream   6 GB     4.3
# 4              4     OPPO     A53   Electric Black   4 GB     4.5
# ...          ...      ...     ...              ...    ...     ...
# 3109        3109  SAMSUNG  M52 5G    Blazing Black   6 GB     4.3
# 3110        3110  SAMSUNG  M52 5G         Icy Blue   6 GB     4.3
# 3111        3111  SAMSUNG  M52 5G         Icy Blue   8 GB     4.3
# 3112        3112  SAMSUNG  M52 5G      Slate Black   8 GB     4.2
# 3113        3113  SAMSUNG  M52 5G         Sky Blue   8 GB     4.2
#
#       Selling Price  Original Price
# 0             11990           15990
# 1             11990           15990
# 2             13990           17990
# ...

# %%
y=n.replace({4.3:4.44})
y
# Out:
#       Unnamed: 0    Brand   Model            Color Memory  Rating  \
# 0              0     OPPO     A53  Moonlight Black   4 GB    4.50
# 1              1     OPPO     A53       Mint Cream   4 GB    4.50
# 2              2     OPPO     A53  Moonlight Black   6 GB    4.44
# 3              3     OPPO     A53       Mint Cream   6 GB    4.44
# 4              4     OPPO     A53   Electric Black   4 GB    4.50
# ...          ...      ...     ...              ...    ...     ...
# 3109        3109  SAMSUNG  M52 5G    Blazing Black   6 GB    4.44
# 3110        3110  SAMSUNG  M52 5G         Icy Blue   6 GB    4.44
# 3111        3111  SAMSUNG  M52 5G         Icy Blue   8 GB    4.44
# 3112        3112  SAMSUNG  M52 5G      Slate Black   8 GB    4.20
# 3113        3113  SAMSUNG  M52 5G         Sky Blue   8 GB    4.20
#
#       Selling Price  Original Price
# 0             11990           15990
# 1             11990           15990
# 2             13990           17990
# ...

# %%
new=y['Model'].isin(['M52 5G'])
y[new]
# Out:
#       Unnamed: 0    Brand   Model          Color Memory  Rating  \
# 3108        3108  SAMSUNG  M52 5G  Blazing Black   8 GB    4.44
# 3109        3109  SAMSUNG  M52 5G  Blazing Black   6 GB    4.44
# 3110        3110  SAMSUNG  M52 5G       Icy Blue   6 GB    4.44
# 3111        3111  SAMSUNG  M52 5G       Icy Blue   8 GB    4.44
# 3112        3112  SAMSUNG  M52 5G    Slate Black   8 GB    4.20
# 3113        3113  SAMSUNG  M52 5G       Sky Blue   8 GB    4.20
#
#       Selling Price  Original Price
# 3108          27839           31889
# 3109          25990           25990
# 3110          25489           28449
# 3111          27239           31489
# 3112          22989           22989
# 3113          20350           22595
